# %% [markdown]
# # after all tree have been created

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = pd.read_pickle('./saved_variables/X_y_train_test')
df_X, df_y, df_data = pd.read_pickle('saved_variables/df_X_y_data')
feature_names, class_names = pd.read_pickle('saved_variables/feature_class_names')

# %%
clf = RandomForestClassifier(random_state=0, min_impurity_split=None, min_samples_split=2)
clf.fit(X_train, y_train)
disp = plot_precision_recall_curve(clf, X_test, y_test)
#disp.ax_.set_title('2-class Precision-Recall curve: '
#                   'AP={0:0.2f}'.format(average_precision))

# %%
clf = DecisionTreeClassifier(random_state=0, min_impurity_split=None, min_samples_split=2)
clf.fit(X_train, y_train)
disp = plot_precision_recall_curve(clf, X_test, y_test)
#disp.ax_.set_title('2-class Precision-Recall curve: '
#                   'AP={0:0.2f}'.format(average_precision))

# %% [markdown]
# # parralel coordinates plot for confusion matrix data
# https://plotly.com/python/parallel-coordinates-plot/
